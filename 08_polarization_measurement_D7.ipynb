# %% [markdown]
# <a href="https://colab.research.google.com/github/ChenXie-astro/corgietc/blob/main/08_polarization_measurement_D7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polarization Measurement
#
# This notebook demonstrates setting up integration time calculations in POL mode.

# %% [markdown]
# If running via Google Colab, you must first execute the contents of notebook `00_Google_Colab_Setup.ipynb` (only if you have never done so previously). Then execute all cells tagged with &#128992;.  If running via a local installation, you should skip all of the colab-specific (&#128992;) cells.

# %% [markdown]
# ## 🟠 Setup for Google Colab Use

# %% [markdown]
# ### 🟠 Run the next cell to mount the Google Drive
#
# You will receive some or all of the following prompts:
#
# * Warning: This notebook was not authored by Google - Click "Run Anyway"
# * Permit this notebook to access your Google Drive files? - Click "Connect to Google Drive"
# * A new browser window will prompt you to select an account and authorize access
#   * Select the Google account you wish to use and click Continue on each subsequent screen until the dialog vanishes
#
# Upon completion of cell execution, you should see `Mounted at /content/drive`

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### 🟠 Run the next cell to change to the corgietc directory and install the required software
#
# This process should take less than a minute, but, depending on bandwidth availability, may take as long as a few minutes. You will see a variety of messages about package downloads.  Upon completion of cell execution, you should see `Sucessfully installed` followed by a list of installed packages and their versions.
#
# You may see the prompt "Restart session".  You do not need to do this - click 'Cancel'.

# %%
# This cell should *only* be executed if running the notebook in Google Colab
import os

# Google top level drive dir
drive_dir = "/content/drive/MyDrive/"

# directory path
corgietc_dir = 'corgietc'
corgietc_path = os.path.join(drive_dir, corgietc_dir)
cgi_noise_repo_path = os.path.join(corgietc_path, "cgi_noise")
corgietc_repo_path = os.path.join(corgietc_path, "corgietc")
corgietc_notebooks_path = os.path.join(corgietc_repo_path, "Notebooks")

# Change to the cgi_noise repo path and update the repo
os.chdir(cgi_noise_repo_path)
# !git pull

# Install the backend and all requirements - this can also take a little while
# !pip install .

# Change to the corgietc repo path and update the repo
os.chdir(corgietc_repo_path)
# !git pull

# Install the backend and all requirements - this can also take a little while
# !pip install .

# Refresh package list to pick up new installations
import site
site.main()

# Change to the Notebooks directory
os.chdir(corgietc_notebooks_path)
# Out:
# Already up to date.
# Processing /content/drive/MyDrive/corgietc/cgi_noise
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cgi_noise==1.4.0) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from cgi_noise==1.4.0) (2.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from cgi_noise==1.4.0) (6.0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from cgi_noise==1.4.0) (3.17.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from cgi_noise==1.4.0) (5.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->cgi_noise==1.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->cgi_noise==1.4.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->cgi_noise==1.4.0) (2025.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->cgi_noise==1.4.0) (0.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->cgi_noise==1.4.0) (1.17.0)
# Building wheels for collected packages: cgi_noise
#   Building wheel for cgi_noise (pyproject.toml) ... done
#   Created wheel for cgi_noise: filename=cgi_noise-1.4.0-py3-none-any.whl size=79254 sha256=35286bfe7878f2daa3fb094fccea40f62da71601940303f3934b10aeacea5599
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9f2wsz51/wheels/f2/19/73/05bec0cc382a0c9da9b0f08a7c72962606b1c0cd7d9064b542
# Successfully built cgi_noise
# Installing collected packages: cgi_noise
#   Attempting uninstall: cgi_noise
#     Found existing installation: cgi_noise 1.4.0
#     Uninstalling cgi_noise-1.4.0:
#       Successfully uninstalled cgi_noise-1.4.0
# Successfully installed cgi_noise-1.4.0
# Already up to date.
# Processing /content/drive/MyDrive/corgietc/corgietc
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: EXOSIMS>=3.6.5 in /usr/local/lib/python3.12/dist-packages (from corgietc==1.6.0) (3.6.5)
# Requirement already satisfied: cgi_noise>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from corgietc==1.6.0) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cgi_noise>=1.4.0->corgietc==1.6.0) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from cgi_noise>=1.4.0->corgietc==1.6.0) (2.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from cgi_noise>=1.4.0->corgietc==1.6.0) (6.0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from cgi_noise>=1.4.0->corgietc==1.6.0) (3.17.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.12/dist-packages (from cgi_noise>=1.4.0->corgietc==1.6.0) (5.2.0)
# Requirement already satisfied: scipy>=1.7.2 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (1.16.3)
# Requirement already satisfied: astropy>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (7.2.0)
# Requirement already satisfied: jplephem>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (2.24)
# Requirement already satisfied: ortools>=9.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (9.15.6755)
# Requirement already satisfied: h5py>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (3.15.1)
# Requirement already satisfied: astroquery>=0.4.8 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (0.4.11)
# Requirement already satisfied: exo-det-box in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (0.0.2)
# Requirement already satisfied: tqdm>=4.59 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (4.67.3)
# Requirement already satisfied: MeanStars>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (3.6.1)
# Requirement already satisfied: synphot>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (1.7.0)
# Requirement already satisfied: ipyparallel>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (8.8.0)
# Requirement already satisfied: keplertools>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (1.4.1)
# Requirement already satisfied: angutils>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from EXOSIMS>=3.6.5->corgietc==1.6.0) (1.0.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.10.27.0.39.10 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.2026.2.23.0.48.33)
# Requirement already satisfied: packaging>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from astropy>=6.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (26.0)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.12/dist-packages (from astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.32.4)
# Requirement already satisfied: beautifulsoup4>=4.8 in /usr/local/lib/python3.12/dist-packages (from astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.13.5)
# Requirement already satisfied: html5lib>=0.999 in /usr/local/lib/python3.12/dist-packages (from astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (1.1)
# Requirement already satisfied: keyring>=15.0 in /usr/local/lib/python3.12/dist-packages (from astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (25.7.0)
# Requirement already satisfied: pyvo>=1.5 in /usr/local/lib/python3.12/dist-packages (from astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (1.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.4.2)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.4)
# Requirement already satisfied: ipykernel>=4.4 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (6.17.1)
# Requirement already satisfied: ipython>=4 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (7.34.0)
# Requirement already satisfied: jupyter-client>=5 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (7.4.9)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=18 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (26.2.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (6.5.1)
# Requirement already satisfied: traitlets>=4.3 in /usr/local/lib/python3.12/dist-packages (from ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (5.7.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from keplertools>=1.2.1->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.0.12)
# Requirement already satisfied: absl-py>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools>=9.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.4.0)
# Requirement already satisfied: protobuf<6.34,>=6.33.1 in /usr/local/lib/python3.12/dist-packages (from ortools>=9.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (6.33.5)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from ortools>=9.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.15.0)
# Requirement already satisfied: immutabledict>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from ortools>=9.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->cgi_noise>=1.4.0->corgietc==1.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->cgi_noise>=1.4.0->corgietc==1.6.0) (2025.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->cgi_noise>=1.4.0->corgietc==1.6.0) (0.6.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.8->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.8.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib>=0.999->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.5.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (1.8.15)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (1.6.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.9.0)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=5->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (5.9.1)
# Requirement already satisfied: SecretStorage>=3.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.5.0)
# Requirement already satisfied: jeepney>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.9.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.4.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.4.0)
# Requirement already satisfied: jaraco.context in /usr/local/lib/python3.12/dist-packages (from keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (6.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (2026.2.25)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.8.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=5->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (4.9.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4->ipyparallel>=8.0.0->EXOSIMS>=3.6.5->corgietc==1.6.0) (0.7.0)
# Requirement already satisfied: cryptography>=2.0 in /usr/local/lib/python3.12/dist-packages (from SecretStorage>=3.2->keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (43.0.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from jaraco.classes->keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (10.8.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=2.0->SecretStorage>=3.2->keyring>=15.0->astroquery>=0.4.8->EXOSIMS>=3.6.5->corgietc==1.6.0) (3.0)
# Building wheels for collected packages: corgietc
#   Building wheel for corgietc (pyproject.toml) ... done
#   Created wheel for corgietc: filename=corgietc-1.6.0-py3-none-any.whl size=30938 sha256=c4bca2b83f737d4d880404dc1b9fa777f276a2886a12c3685e1744a4f6df33d4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ydk5nx35/wheels/cd/7d/e6/2d71b765c681eea8fbf049288fe08e955d4582a06ebde58945
# Successfully built corgietc
# Installing collected packages: corgietc
#   Attempting uninstall: corgietc
#     Found existing installation: corgietc 1.6.0
#     Uninstalling corgietc-1.6.0:
#       Successfully uninstalled corgietc-1.6.0
# Successfully installed corgietc-1.6.0

# %% [markdown]
# ### 🟠 Import jupyter widget for Colab

# %%
# need to import third party jupyter widget
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ## All Cells from this point should be run for both Colab and local installations

# %%
# import all required packages
from corgietc.corgietc import corgietc
import os
import json
import yaml
from EXOSIMS.Prototypes.TargetList import TargetList
import EXOSIMS.Prototypes.TimeKeeping
import EXOSIMS.Observatory.ObservatoryL2Halo
import EXOSIMS.PlanetPhysicalModel.ForecasterMod
from EXOSIMS.util.deltaMag import deltaMag
from EXOSIMS.util.phaseFunctions import phi_lambert
from keplertools import fun as kepler_fun
import copy
import astropy.units as u
from astropy.time import Time
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Defining all other parameters, Constructing EXOSIMS Objects
#
# All EXOSIMS objects are constructed via an input specification - a dictionary of key/value pairs, that can be read from a JSON-formatted file stored on disk. Passing such an input specification to a TargetList automatically creates the TargetList, along with all other EXOSIMS modules required by the TargetList, which includes the OpticalSystem and ZodiacalLight modules (the ones we need for doing our calculations). More info on EXOSIMS objects is available here: https://exosims.readthedocs.io/en/latest/intro.html#framework
#
# corgietc provides a default input specification, which we will now load:

# %%
scriptfile = os.path.join(os.environ["CORGIETC_DATA_DIR"], "scripts", "CGI_Noise.json")
with open(scriptfile, "r") as f:
    specs = json.loads(f.read())

# %% [markdown]
# In order to deminstrate how contrast degradation works, we first need to define various input components for Cp_Cb_Csp and calc_intTime functions. Those are, Target List (TL), Optical System (OS), etc. See 01_Anatomy_of_an_Integration_Time_Calculation.ipynb Notebook for further details.

# %%
TL = EXOSIMS.Prototypes.TargetList.TargetList(**copy.deepcopy(specs))
OS = TL.OpticalSystem
ZL = TL.ZodiacalLight
mode = OS.observingModes[0]
sInds = 0
JEZ = TL.JEZ0[mode["hex"]]/(4.1536**2)
fZ = np.repeat(TL.ZodiacalLight.fZ0, 1)
dMag = np.array([17.5])
WA = np.array([7.5]) * (mode["lam"]/OS.pupilDiam).to(u.arcsec, equivalencies=u.dimensionless_angles())
# Out:
# /usr/local/lib/python3.12/dist-packages/EXOSIMS/Prototypes/TargetList.py:381: UserWarning: binary_filter is None but filterBinaries is False. Using binary_filter value of None.
#   warnings.warn(
# Imported StarCatalog (prototype) from EXOSIMS.Prototypes.StarCatalog
# Imported corgietc (named file) from /content/drive/[...]ietc/corgietc/corgietc.py
# Imported Stark (implementation) from EXOSIMS.ZodiacalLight.Stark
# Imported PostProcessing (prototype) from EXOSIMS.Prototypes.PostProcessing
# Imported GalaxiesFaintStars (implementation) from EXOSIMS.BackgroundSources.GalaxiesFaintStars
# Imported Completeness (prototype) from EXOSIMS.Prototypes.Completeness
# Imported PlanetPopulation (prototype) from EXOSIMS.Prototypes.PlanetPopulation
# Imported ForecasterMod (implementation) from EXOSIMS.PlanetPhysicalModel.ForecasterMod
# 1 targets imported from star catalog.
# 1 targets remain after removing those where spectral class cannot be established.
# 1 targets remain after removing white dwarfs and subdwarfs
# 1 targets remain after nan filtering.
# 1 targets remain after removing zero luminosity targets.
# Loaded JEZ0 for mode e0801f22e5abd19dc9f9ed6a72afd219 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_e0801f22e5abd19dc9f9ed6a72afd219.JEZ0
# Loaded JEZ0 for mode 4553282203365db91748949ce1af33bd from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_4553282203365db91748949ce1af33bd.JEZ0
# Loaded JEZ0 for mode 6977ed0120e283f729365f92422770e1 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_6977ed0120e283f729365f92422770e1.JEZ0
# Loaded JEZ0 for mode 8b5da04361d1cc055ef28f9d85165ef2 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_8b5da04361d1cc055ef28f9d85165ef2.JEZ0
# Loaded JEZ0 for mode 71b6350fdb415508db2f2c7ab55fccb6 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_71b6350fdb415508db2f2c7ab55fccb6.JEZ0
# Loaded JEZ0 for mode 9bda35c3cbfa0a1c00ea47e862f203e3 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_9bda35c3cbfa0a1c00ea47e862f203e3.JEZ0
# Loaded JEZ0 for mode 0f604bad94af021c51e87d48ad2d1538 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_0f604bad94af021c51e87d48ad2d1538.JEZ0
# Loaded JEZ0 for mode ff7b315778641ee5bf988cde30c2ba46 from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5nStars_1_mode_ff7b315778641ee5bf988cde30c2ba46.JEZ0
# Loaded star fluxes values from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5_nStars_1_mode_e0801f22e5abd19dc9f9ed6a72afd219.star_fluxes
# Loaded intCutoff_dMag values from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5_corgietc_Stark_vals_ab4de219512b37abf36da4a8cf239fa8_mode_e0801f22e5abd19dc9f9ed6a72afd219.intCutoff_dMag
# Loaded intCutoff_comp values from /root/.EXOSIMS/cache/v3.6.5/TargetList_StarCatalog_3a93f39cdb9423860f2d81a6c0c25bb5_Completeness_vals_8ee4c08e2956d5783bd078aa93b47ff5.intCutoff_comp

# %%
# for mode in OS.observingModes:
#     print(mode["Scenario"])
print(mode["Scenario"])
# Out:
# OPT_IMG_NFB1_HLC

# %% [markdown]
# ## Demostrating polarization calculations
#
# By default, the `mode` dictionary is set up to simulate imaging integrations.  If we compute the integration time with the default mode values, we will get the same result as in the first demo notebook (01_Anatomy_of_an_Integration_Time_Calculation.ipynb):

# %%
intTimes = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
intTimes.to(u.s)
# Out:
# <Quantity [126.90022133] s>

# %% [markdown]
# In order to simulate a pol-mode observation, we need to add a `polfraction` ($p_{in}$) keyword  and a `theta` ($\theta_{in}$) keyword to the `mode` dictionary to encode the polarization fraction we wish to simulate.
#
# The total number of source photons for the imaging mode = Cp (in ph/s)
#
# In polarization mode, the additional transmission losses compared to the imaging mode:
#
# POL0 (transmission)=96.2 $\pm$ 0.7 \%
#
# POL45 (transmission)=96.5 $\pm$ 1.3 \%
#
# When the photons then pass through the Wollastons:
#
# Photons through POL0 ($Cp_{POL0}$) =Cp $\times$ POL0 (transmission)
#
# Photons through POL45 ($Cp_{POL45}$)=Cp $\times$ POL45 (transmission)
#
# POL0 will split Cp into I(0) and I(90)
#
# POL45 will split Cp into I(45) and I(135)
#
# For a known value of polarization fraction ($p_{in}$) and polarization position angle ($\theta_{in}$), the photons through the two Wollastons would be:
# $$
# \begin{aligned}
# I(0)&=&\frac{Cp_{POL0}}{2}*(1+p_{in}*\cos{2\theta_{in}})\\
# I(90)&=&\frac{Cp_{POL0}}{2}*(1-p_{in}*\cos{2\theta_{in}})\\
# I(45)&=&\frac{Cp_{POL45}}{2}*(1+p_{in}*\sin{2\theta_{in}})\\
# I(135)&=&\frac{Cp_{POL45}}{2}*(1-p_{in}*\sin{2\theta_{in}})\\
# \end{aligned}
# $$
#
# Using these intensities through the Wollastons, the measured Q, U and I can be estimated as:
#
# $$
# \begin{aligned}
# I_{in}&= \frac{1}{2}(I(0)+I(90)+I(45)+I(135))\\
# Q_{in}&= I(0)-I(90) \\
# U_{in}&=I(45)-I(135)
# \end{aligned}
# $$
#
# Let's define our system as composed of a Wollaston (starting with POL0) and system model as follows:
# $$
# \begin{aligned}
# S_{meas} &= M_{System}S_{in} \\
# S_{in} &= [M_{System}]^{-1}S_{meas}
# \end{aligned}
# $$
#
#
# $$
# \begin{equation*}
# \begin{pmatrix}
# I_{m}  \\
# Q_{m}\\
# U_{m}\\
# V_{m}
# \end{pmatrix} =
# \begin{pmatrix}
# m_{1,1} & m_{1,2} & m_{1,3} & m_{1,4} \\
# m_{2,1} & m_{2,2} & m_{2,3} & m_{2,4} \\
# m_{3,1} & m_{3,2} & m_{3,3} & m_{3,4} \\
# m_{4,1} & m_{4,2} & m_{4,3} & m_{4,4}
# \end{pmatrix}^{-1}
# \begin{pmatrix}
# I_{in}  \\
# Q_{in}\\
# U_{in}\\
# 0
# \end{pmatrix}.
# \end{equation*}
# $$
#
# $M_{System}$ is called a Mueller matrix and it is defined for different science instruments (NF_B1_Imager, WF_B4_Imager, etc)
#
# Once we get the Input Stokes vectors, the polarization fraction  ($p_f$ ) is estimated as:
#
# $$
# \begin{aligned}
# p_f &= \frac{\sqrt{Q_{m}^2+U_{m}^2}}{I_{m}}\\
# \theta_{f}&=0.5\arctan(\frac{U_{m}}{Q_{m}})\\
# \end{aligned}
# $$
#
# Now, we have the input polarization fraction that does not depend on the exposure time.
#
# If the keyword `theta` isn't defined, then it is assumed to be 0 for the polarization fraction.

# %%
mode["polfraction"] = 0.5
intTimes = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
intTimes.to(u.s)
# Out:
# <Quantity [534.42505538] s>

# %% [markdown]
# with the `theta` keyword:

# %%
# mode["theta"] = np.pi/4
# mode["theta"] = np.pi/3
intTimes = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
intTimes.to(u.s)
# Out:
# <Quantity [532.22447473] s>

# %% [markdown]
# As expected, a 50% polarization fraction leads to approximately a 4x increase in the required integration time.

# %% [markdown]
# In order to reset the mode back to imaging, we can either remove the `polfraction` keyword, or set it to NaN:

# %%
mode["polfraction"] = np.nan
intTimes = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
intTimes.to(u.s)
# Out:
# <Quantity [126.90022133] s>

# %% [markdown]
# Note that if we set the polarization fraction to exactly zero, we will get a NaN integration time, as it is impossible to integrate for long enough to measure exactly zero polarization:

# %%
mode["polfraction"] = 0
intTimes = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
intTimes.to(u.s)
# Out:
# <Quantity [nan] s>

# %% [markdown]
# We can also scan through a range of polarization fractions to see where we hit the noise floor:

# %%
ps = np.linspace(0.1, 0.9, 100)
intTimes = np.zeros(len(ps))*u.d
mode["theta"] = np.pi/4

for j, p in enumerate(ps):
    mode["polfraction"] = p
    intTimes[j] = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)[0]

mode["SNR"] = 10
intTimes2 = np.zeros(len(ps))*u.d

for j, p in enumerate(ps):
    mode["polfraction"] = p
    intTimes2[j] = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)[0]

mode["SNR"] = 5

plt.figure()
plt.semilogy(ps, intTimes, label = 'SNR = 5')
plt.semilogy(ps, intTimes2, label = 'SNR = 10')
plt.xlabel(rf"Polarization Fraction")
plt.ylabel(f"Integration Time ({intTimes.unit})")
plt.title(f"Polarization Fraction vs Integration Time ({intTimes.unit}) for different SNRs")
plt.legend();

# %% [markdown]
# We can compare the imaging mode and polarization mode to see that the polarization mode integration time is always higher than the imaging mode integration time:

# %%
mode["polfraction"] = np.nan

ps = np.linspace(0.1, 0.9, 100)
times_img = np.zeros(len(ps))*u.d
times_p = np.zeros(len(ps))*u.d

for j, p in enumerate(ps):
    times_img[j] = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)[0]

for j, p in enumerate(ps):
    mode["polfraction"] = p
    times_p[j] = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)[0]


plt.figure()
plt.semilogy(ps, times_img, label = 'imaging mode')
plt.semilogy(ps, times_p, label = 'polarization mode')
plt.xlabel(rf"Polarization Fraction")
plt.ylabel(f"Integration Time ({times_img.unit})")
plt.title(rf"Integration Time (d) vs Polarization Fraction for $\theta = \pi/4$, contrast = 1e-7 and SNR = 5")
plt.legend()
plt.show()

# %%
mode["polfraction"] = np.nan
intTime_img = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
print(f"Imaging mode integration time: {intTime_img.to(u.s)}")
mode["polfraction"] = 1
intTime_p = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
print(f"Polarization mode integration time at polfraction 1 : {intTime_p.to(u.s)}")
# Out:
# Imaging mode integration time: [126.90022133] s
# Polarization mode integration time at polfraction 1 : [133.39859124] s

# %% [markdown]
# ### Critical Polfraction

# %% [markdown]
# The integration time varies with different polfractions and contrast limits. It is negative below certain ($p_f$, $\Delta$mag). To calculate above what values of ($p_f$, $\Delta$mag) it is possible to calculate the integration time, we can use the function `calc_critical_polfraction`

# %%
dMags = np.linspace(12, 21, 50)
p_crit = []
for i in range(len(dMags)):
    p_crit.append(OS.calc_critical_polfraction(TL, sInds, fZ, JEZ, dMags[i], WA, mode, TK=None))
plt.figure()
plt.plot(dMags, p_crit)
plt.xlabel(rf"$\Delta$Mag")
plt.ylabel(f"Critical Polarization Fraction")
plt.grid()
plt.show()

# %% [markdown]
# ### Noise propagation for polarization mode

# %% [markdown]
# For the current imaging mode, the poisson noise source is $r_n$ and $f_{\Delta I}^2 r_{sp}^2 t^2$ is the post-processing noise.For the RDI post processing noise factor we have the speckle signal multiplied with the post-processing factor.
#
# $$
# \begin{aligned}
# r_n&=& r_{pl}+r_{sp}+r_{zo}+r_{det} \\
# \sigma^2_{tot}&=& r_{n}t +f_{\Delta I}^2 r_{sp}^2 t^2 \\
# \sigma^2_{tot}&=&C_bpol+C_{sp}pol
# \end{aligned}
# $$
# For pol mode, the noise for the detector doubles as the measurements have to be carried out on two apertures $C_b$ changes as
#
# $$
# \begin{aligned}
#     C_bpol &= & r_{pl}t +r_{sp}t+r_{zo}t+2*r_{det}t\\
# \end{aligned}
# $$
#
# For the speckle noise, in addition to the RDI postprocessing factor, we will have a polarization speckle contrast term $C_{pab}$
#
# $$
# \begin{aligned}
#     C_{sp}pol &=& f_{\Delta I}^2 r_{sp}^2 t^2+C_{pab}^2t^2
# \end{aligned}
# $$
#
# To add polarization speckle contrast, we need to add the keyword `Cp_ab` to the mode. If `Cp_ab` is not defined, it is assumed to be 0.

# %%
mode["polfraction"] = 0.5
mode["theta"] = np.pi/4
intTime1 = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
print(rf"Integration time with 0 polarization speckle contrast: {intTime1.to(u.s).value.item():.15f}")
mode["Cp_ab"] = 1e-8
intTime2 = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
print(rf"Integration time with 1e-8 polarization speckle contrast: {intTime2.to(u.s).value.item():.15f}")
mode["Cp_ab"] = 1e-9
intTime3 = OS.calc_intTime(TL, sInds, fZ, JEZ, dMag, WA, mode)
print(rf"Integration time with 1e-9 polarization speckle contrast: {intTime3.to(u.s).value.item():.15f}")
# Out:
# Integration time with 0 polarization speckle contrast: 533.963326429851350
# Integration time with 1e-8 polarization speckle contrast: 533.963326429922631
# Integration time with 1e-9 polarization speckle contrast: 533.963326429852032
